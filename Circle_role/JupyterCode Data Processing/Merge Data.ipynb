# %%
import pandas as pd
Zillow = pd.read_csv('Zillowdata.csv')
states = pd.read_csv('FIPS.csv')
COVID= pd.read_csv('cleancovid.csv')
income= pd.read_csv('incomeall.csv')
raceeth= pd.read_csv('RaceEthnicity.csv')
RU= pd.read_csv('ruralurban.csv')
pop= pd.read_csv('Population.csv')
Zillow
# Out:
#       Unnamed: 0  RegionID  SizeRank          RegionName RegionType StateName  \
# 0              0      3101         0  Los Angeles County     county        CA
# 1              1       139         1         Cook County     county        IL
# 2              2      1090         2       Harris County     county        TX
# 3              3      2402         3     Maricopa County     county        AZ
# 4              4      2841         4    San Diego County     county        CA
# ...          ...       ...       ...                 ...        ...       ...
# 2835        2835       828      3104       Alpine County     county        CA
# 2836        2836      2345      3113     Hinsdale County     county        CO
# 2837        2837      1933      3114      Mineral County     county        CO
# 2838        2838      1648      3129      Daggett County     county        UT
# 2839        2839      2518      3132     San Juan County     county        CO
#
# ...

# %%
states['C_Sa']=states['name'].astype(str)+','+states['state_Ab'].astype(str)
states
states.to_csv("Fip-it2.csv")

# %%
Zillow['C_Sa']=Zillow['RegionName'].astype(str)+','+Zillow['StateName'].astype(str)
Zillow
# Out:
#       Unnamed: 0  RegionID  SizeRank          RegionName RegionType StateName  \
# 0              0      3101         0  Los Angeles County     county        CA
# 1              1       139         1         Cook County     county        IL
# 2              2      1090         2       Harris County     county        TX
# 3              3      2402         3     Maricopa County     county        AZ
# 4              4      2841         4    San Diego County     county        CA
# ...          ...       ...       ...                 ...        ...       ...
# 2835        2835       828      3104       Alpine County     county        CA
# 2836        2836      2345      3113     Hinsdale County     county        CO
# 2837        2837      1933      3114      Mineral County     county        CO
# 2838        2838      1648      3129      Daggett County     county        UT
# 2839        2839      2518      3132     San Juan County     county        CO
#
# ...

# %%
Zillow1=Zillow.merge(states, on="C_Sa")
Zillowfips=Zillow1.set_index('fips')

Zillowfips
# Out:
#        Unnamed: 0_x  RegionID  SizeRank          RegionName RegionType  \
# fips
# 6037              0      3101         0  Los Angeles County     county
# 17031             1       139         1         Cook County     county
# 48201             2      1090         2       Harris County     county
# 4013              3      2402         3     Maricopa County     county
# 6073              4      2841         4    San Diego County     county
# ...             ...       ...       ...                 ...        ...
# 6003           2835       828      3104       Alpine County     county
# 8053           2836      2345      3113     Hinsdale County     county
# 8079           2837      1933      3114      Mineral County     county
# 49009          2838      1648      3129      Daggett County     county
# 8111           2839      2518      3132     San Juan County     county
#
#       StateName State                                 Metro  StateCodeFIPS  \
# fips
# ...

# %%
ZillowT=Zillow1.set_index('fips').T
ZillowT.reset_index(inplace=True)
ZillowT1=ZillowT
ZillowT1['month']=ZillowT['index'].str.split('/').str[0]
ZillowT1['year']=ZillowT['index'].str.split('/').str[-1]

ZillowT1.tail(40)

# %%
ZillowTT=ZillowT1.set_index('month').T
ZillowTT

# %%
COVID['fip-year-month']=COVID['fips'].astype(str)+'-'+COVID['Unnamed: 0'].astype(str)+'-'+COVID['date'].astype(str)
COVID['fip-year']=COVID['fips'].astype(str)+'-'+COVID['Unnamed: 0'].astype(str)
COVID
COVID.to_csv("clenCOVID-it2.csv")

# %%
income['fip-year']=income['fips'].astype(str)+'-'+income['Unnamed: 0'].astype(str)
income
income.to_csv("Income-it2.csv")

# %%
raceeth=raceeth.merge(states, on="C_S")
raceeth
pop=pop.merge(states, on="C_S")
pop
# Out:
#        Unnamed: 0_x  YEAR                     C_S  POPESTIMATE   MFratio  \
# 0                 9  2017  Autauga County,Alabama        55448  0.951913
# 1                10  2018  Autauga County,Alabama        55533  0.949621
# 2                11  2019  Autauga County,Alabama        55769  0.943780
# 3                 1  2020  Autauga County,Alabama        58877  0.953256
# 4                 2  2021  Autauga County,Alabama        59095  0.946347
# ...             ...   ...                     ...          ...       ...
# 15675         43997  2017   Weston County,Wyoming         6962  1.111617
# 15676         43998  2018   Weston County,Wyoming         6895  1.107918
# 15677         43999  2019   Weston County,Wyoming         6880  1.107198
# 15678          9427  2020   Weston County,Wyoming         6809  1.129143
# 15679          9428  2021   Weston County,Wyoming         6745  1.136522
#
#        POPEST_MALE  POPEST_FEM  MEDIAN_AGE_TOT  UNDER5_TOT  AGE513_TOT  \
# ...

# %%
raceeth['fip-year']=raceeth['fips'].astype(str)+'-'+raceeth['YEAR'].astype(str)
raceeth
raceeth.to_csv("raceeth-it2.csv")
pop['fip-year']=pop['fips'].astype(str)+'-'+pop['YEAR'].astype(str)
pop
pop.to_csv("Population-it2.csv")

# %%
RU['fips']=RU["FIPS"]
COVID['fips']=COVID['fips'].astype(str)
states['fips']=states['fips'].astype(str)
RU['fips']=RU['fips'].astype(str)
RU.merge(states, on='fips')
RU
# Out:
#       Unnamed: 0   FIPS State     County_Name Population_2010  RUCC_2013  \
# 0              0  01001    AL  Autauga County          54,571        2.0
# 1              1  01003    AL  Baldwin County         182,265        3.0
# 2              2  01005    AL  Barbour County          27,457        6.0
# 3              3  01007    AL     Bibb County          22,915        1.0
# 4              4  01009    AL   Blount County          57,322        1.0
# ...          ...    ...   ...             ...             ...        ...
# 3235        3235  00nan   NaN             NaN             NaN        NaN
# 3236        3236  00nan   NaN             NaN             NaN        NaN
# 3237        3237  00nan   NaN             NaN             NaN        NaN
# 3238        3238  00nan   NaN             NaN             NaN        NaN
# 3239        3239  00nan   NaN             NaN             NaN        NaN
#
#                                             Description   fips
# ...

# %%
RU.dropna()
RU.to_csv("ruralurban-it2.csv")

# %%
COVID.dtypes
COVID['fips']=COVID['fips'].astype(str)
COVID
# Out:
#        Unnamed: 0   fips  date  cases
# 0            2020   1001     3     43
# 1            2020   1001     4    731
# 2            2020   1001     5   3660
# 3            2020   1001     6  11110
# 4            2020   1001     7  24241
# ...           ...    ...   ...    ...
# 67348        2021  56045     8  22442
# 67349        2021  56045     9  25372
# 67350        2021  56045    10  30816
# 67351        2021  56045    11  35174
# 67352        2021  56045    12  38058
#
# [67353 rows x 4 columns]

# %%
COVIDT=COVID.set_index(['fip-year-month']).T
COVIDT

# %%
#income1=income.merge(COVID, on='fip-year')
#income2=income.rename(columns={"fip-year-month_y":'fip-year-month'} , index=['fip-year-month'])
#income3=income2[['fip-year-month','PCIncome']
#print(income2.set_index(['fip-year-month_y']).T)
#income3

# %%
COVIDINCOME=pd.concat([COVIDT,income3], ignore_index=True)
COVIDINCOME

# %%
Zillowfips
# Out:
#        1/31/2017  2/28/2017  3/31/2017  4/30/2017  5/31/2017  6/30/2017  \
# fips
# 6037    564461.0   567795.0   570658.0   572179.0   575524.0   579166.0
# 17031   233341.0   235168.0   237553.0   238976.0   239723.0   239413.0
# 48201   183745.0   184165.0   184612.0   185447.0   185949.0   186405.0
# 4013    237000.0   238452.0   240268.0   241526.0   242525.0   243610.0
# 6073    518024.0   521096.0   525041.0   530309.0   535393.0   539166.0
# ...          ...        ...        ...        ...        ...        ...
# 6003    399852.0   401779.0   404017.0   406769.0   408742.0   410048.0
# 8053         NaN        NaN        NaN        NaN        NaN        NaN
# 8079         NaN        NaN        NaN        NaN        NaN        NaN
# 49009   178859.0   180403.0   182158.0   183671.0   185112.0   186947.0
# 8111    287526.0   289917.0   290315.0   290092.0   289739.0   290411.0
#
#        7/31/2017  8/31/2017  9/30/2017  10/31/2017  ...  3/31/2021  4/30/2021  \
# ...

# %%
Zillowfips.drop(columns=['Unnamed: 0_x','RegionID','SizeRank','RegionName','StateName','State','Metro','RegionType',"StateCodeFIPS","MunicipalCodeFIPS",'C_Sa','Unnamed: 0_y','name',"state_Ab"], axis=1)
Zillowfips=Zillowfips.drop(Zillowfips.iloc[:, 0:10],axis = 1)
#Zillowdrop=Zillow1.drop(Zillowfips.iloc[:, 0:10],axis = 1)
Zillowfips=Zillowfips.drop(Zillowfips.iloc[:, -6:],axis = 1)
#Zillowdrop.dtypes
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1648\3838141865.py in <module>
#       4 Zillowfips=Zillowfips.drop(Zillowfips.iloc[:, -6:],axis = 1)
#       5 #Zillowdrop.dtypes
# ----> 6 Zillowfips=Zillowfips[Zillowfips.YEAR <=2019]
#       7 Zillowfips
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'YEAR'

# %%
df=Zillowfips.stack(level=0)
df
df.to_csv('Zillow_it2.csv')

# %%
Zillowit2= pd.read_csv('Zillow_it2.csv') 
Zillowit2
# Out:
#         fips        Date  cost-house
# 0       6037   1/31/2017      564461
# 1       6037   2/28/2017      567795
# 2       6037   3/31/2017      570658
# 3       6037   4/30/2017      572179
# 4       6037   5/31/2017      575524
# ...      ...         ...         ...
# 156688  8111   8/31/2021      415334
# 156689  8111   9/30/2021      423507
# 156690  8111  10/31/2021      429720
# 156691  8111  11/30/2021      433309
# 156692  8111  12/31/2021      438270
#
# [156693 rows x 3 columns]

# %%
Zillowit2['month']=Zillowit2['Date'].str.split('/').str[0]
Zillowit2['year']=Zillowit2['Date'].str.split('/').str[-1]
Zillowit2['year']=Zillowit2['year'].astype(int)
Zillowit2=Zillowit2[Zillowit2.year >=2019]
Zillowit2
# Out:
#         fips        Date  cost-house month  year
# 24      6037   1/31/2019      635279     1  2019
# 25      6037   2/28/2019      633105     2  2019
# 26      6037   3/31/2019      631271     3  2019
# 27      6037   4/30/2019      630818     4  2019
# 28      6037   5/31/2019      631688     5  2019
# ...      ...         ...         ...   ...   ...
# 156688  8111   8/31/2021      415334     8  2021
# 156689  8111   9/30/2021      423507     9  2021
# 156690  8111  10/31/2021      429720    10  2021
# 156691  8111  11/30/2021      433309    11  2021
# 156692  8111  12/31/2021      438270    12  2021
#
# [95347 rows x 5 columns]

# %%
Zillowit2['fip-year-month']=Zillowit2['fips'].astype(str)+'-'+Zillowit2['year'].astype(str)+'-'+Zillowit2['month'].astype(str)
Zillowit2['fip-year']=Zillowit2['fips'].astype(str)+'-'+Zillowit2['year'].astype(str)
Zillowit2
# Out:
# C:\Users\Juhi Aggarwal\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Juhi Aggarwal\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#         fips        Date  cost-house month  year fip-year-month   fip-year
# 24      6037   1/31/2019      635279     1  2019    6037-2019-1  6037-2019
# ...

# %%
Zillowit2.to_csv('Zillow_it2.csv')

# %%
import pandas as pd
Zillow = pd.read_csv('Zillow_it2.csv')
states = pd.read_csv('Fip-it2.csv')
COVID= pd.read_csv('clenCOVID-it2.csv')
income= pd.read_csv('income-it2.csv')
raceeth= pd.read_csv('raceeth-it2.csv')
RU= pd.read_csv('ruralurban-it2.csv')
pop= pd.read_csv('Population-it2.csv')
Zillow
# Out:
#        Unnamed: 0  fips        Date  cost-house  month  year fip-year-month  \
# 0              24  6037   1/31/2019      635279      1  2019    6037-2019-1
# 1              25  6037   2/28/2019      633105      2  2019    6037-2019-2
# 2              26  6037   3/31/2019      631271      3  2019    6037-2019-3
# 3              27  6037   4/30/2019      630818      4  2019    6037-2019-4
# 4              28  6037   5/31/2019      631688      5  2019    6037-2019-5
# ...           ...   ...         ...         ...    ...   ...            ...
# 95342      156688  8111   8/31/2021      415334      8  2021    8111-2021-8
# 95343      156689  8111   9/30/2021      423507      9  2021    8111-2021-9
# 95344      156690  8111  10/31/2021      429720     10  2021   8111-2021-10
# 95345      156691  8111  11/30/2021      433309     11  2021   8111-2021-11
# 95346      156692  8111  12/31/2021      438270     12  2021   8111-2021-12
#
#         fip-year
# 0      6037-2019
# 1      6037-2019
# ...

# %%
Zillow = Zillow[(Zillow['fips'] <= 56045) & (Zillow['fips']>0)]
Zillowclean = Zillow.filter(['cost-house','fip-year-month','fip-year'], axis=1)
Zillowclean
# Out:
#        cost-house fip-year-month   fip-year
# 0          635279    6037-2019-1  6037-2019
# 1          633105    6037-2019-2  6037-2019
# 2          631271    6037-2019-3  6037-2019
# 3          630818    6037-2019-4  6037-2019
# 4          631688    6037-2019-5  6037-2019
# ...           ...            ...        ...
# 95342      415334    8111-2021-8  8111-2021
# 95343      423507    8111-2021-9  8111-2021
# 95344      429720   8111-2021-10  8111-2021
# 95345      433309   8111-2021-11  8111-2021
# 95346      438270   8111-2021-12  8111-2021
#
# [95347 rows x 3 columns]

# %%
Zillowclean.to_csv('Zillowclean.csv')

# %%
COVID.head(5)
# Out:
#    Unnamed: 0  Unnamed: 0.1  fips  date  cases fip-year-month   fip-year
# 0           0          2020  1001     3     43    1001-2020-3  1001-2020
# 1           1          2020  1001     4    731    1001-2020-4  1001-2020
# 2           2          2020  1001     5   3660    1001-2020-5  1001-2020
# 3           3          2020  1001     6  11110    1001-2020-6  1001-2020
# 4           4          2020  1001     7  24241    1001-2020-7  1001-2020

# %%
COVIDclean = COVID.filter(['cases','fip-year-month','fip-year','fips'], axis=1)
COVIDclean.head(5)
# Out:
#    cases fip-year-month   fip-year  fips
# 0     43    1001-2020-3  1001-2020  1001
# 1    731    1001-2020-4  1001-2020  1001
# 2   3660    1001-2020-5  1001-2020  1001
# 3  11110    1001-2020-6  1001-2020  1001
# 4  24241    1001-2020-7  1001-2020  1001

# %%
COVIDclean['fips']=COVIDclean['fips'].astype(str)
COVIDclean['fips']=COVIDclean['fips'].str.pad(5,'left','0')
COVIDclean
COVIDclean.dtypes
# Out:
# cases              int64
# fip-year-month    object
# fip-year          object
# fips              object
# dtype: object

# %%
COVIDclean.to_csv('COVIDclean.csv')

# %%
income
# Out:
#        Unnamed: 0  Unnamed: 0.1  Unnamed: 1   fips  PCIncome  year    fip-year
# 0               0          2017           1   1001   27824.0  2017   1001-2017
# 1               1          2017           2   1003   29364.0  2017   1003-2017
# 2               2          2017           3   1005   17561.0  2017   1005-2017
# 3               3          2017           4   1007   20911.0  2017   1007-2017
# 4               4          2017           5   1009   22021.0  2017   1009-2017
# ...           ...           ...         ...    ...       ...   ...         ...
# 16102       16102          2021        3218  72147    8834.0  2021  72147-2021
# 16103       16103          2021        3219  72149   12179.0  2021  72149-2021
# 16104       16104          2021        3220  72151   10507.0  2021  72151-2021
# 16105       16105          2021        3221  72153   10231.0  2021  72153-2021
# 16106       16106          2021        3222      0   37638.0  2021      0-2021
#
# ...

# %%
income=income[income.year >=2019]
income.head(5)
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 1  fips  PCIncome  year   fip-year
# 6442        6442          2019           1  1001   29819.0  2019  1001-2019
# 6443        6443          2019           2  1003   32626.0  2019  1003-2019
# 6444        6444          2019           3  1005   18473.0  2019  1005-2019
# 6445        6445          2019           4  1007   20778.0  2019  1007-2019
# 6446        6446          2019           5  1009   24747.0  2019  1009-2019

# %%
incomeclean=income.filter(['PCIncome','fip-year'], axis=1)
incomeclean.head(5)
# Out:
#       PCIncome   fip-year
# 6442   29819.0  1001-2019
# 6443   32626.0  1003-2019
# 6444   18473.0  1005-2019
# 6445   20778.0  1007-2019
# 6446   24747.0  1009-2019

# %%
incomeclean.dtypes
# Out:
# PCIncome    float64
# fip-year     object
# dtype: object

# %%
incomeclean.to_csv('incomeclean.csv')

# %%
raceeth.head(5)
# Out:
#    Unnamed: 0  Unnamed: 0_x  YEAR                     C_S     WA     BA   IA  \
# 0           0             9  2017  Autauga County,Alabama  42606  10816  254
# 1           1            10  2018  Autauga County,Alabama  42641  10883  263
# 2           2            11  2019  Autauga County,Alabama  42490  11252  266
# 3           3            19  2020  Autauga County,Alabama  44580  12136  281
# 4           4            38  2021  Autauga County,Alabama  44442  12425  271
#
#     AA  NA   TOM     NH     H  Unnamed: 0_y  fips            name state_Ab  \
# 0  693  59  1020  53908  1540             0  1001  Autauga County       AL
# 1  671  61  1014  53929  1604             0  1001  Autauga County       AL
# 2  668  58  1035  54116  1653             0  1001  Autauga County       AL
# 3  690  66  1124  57009  1868             0  1001  Autauga County       AL
# 4  711  70  1176  57129  1966             0  1001  Autauga County       AL
#
#      state   fip-year
# 0  Alabama  1001-2017
# ...

# %%
raceeth=raceeth[raceeth.YEAR >=2019]
raceeth.head(5)
# Out:
#    Unnamed: 0  Unnamed: 0_x  YEAR                     C_S      WA     BA  \
# 2           2            11  2019  Autauga County,Alabama   42490  11252
# 3           3            19  2020  Autauga County,Alabama   44580  12136
# 4           4            38  2021  Autauga County,Alabama   44442  12425
# 7           7            25  2019  Baldwin County,Alabama  195303  19625
# 8           8            76  2020  Baldwin County,Alabama  203791  20211
#
#      IA    AA   NA   TOM      NH      H  Unnamed: 0_y  fips            name  \
# 2   266   668   58  1035   54116   1653             0  1001  Autauga County
# 3   281   690   66  1124   57009   1868             0  1001  Autauga County
# 4   271   711   70  1176   57129   1966             0  1001  Autauga County
# 7  1724  2436  155  4322  213197  10368             1  1003  Baldwin County
# 8  1844  2561  160  4573  222174  10966             1  1003  Baldwin County
#
#   state_Ab    state   fip-year
# 2       AL  Alabama  1001-2019
# ...

# %%
raceethclean = raceeth.filter(['fip-year','WA','BA','IA','AA','NA','TOM','NH','H'], axis=1)
raceethclean.head(5)
# Out:
#     fip-year      WA     BA    IA    AA   NA   TOM      NH      H
# 2  1001-2019   42490  11252   266   668   58  1035   54116   1653
# 3  1001-2020   44580  12136   281   690   66  1124   57009   1868
# 4  1001-2021   44442  12425   271   711   70  1176   57129   1966
# 7  1003-2019  195303  19625  1724  2436  155  4322  213197  10368
# 8  1003-2020  203791  20211  1844  2561  160  4573  222174  10966

# %%
raceethclean.dtypes
# Out:
# fip-year    object
# WA           int64
# BA           int64
# IA           int64
# AA           int64
# NA           int64
# TOM          int64
# NH           int64
# H            int64
# dtype: object

# %%
raceethclean.to_csv('raceethclean.csv')

# %%
pop.head(5)
# Out:
#    Unnamed: 0  Unnamed: 0_x  YEAR                     C_S  POPESTIMATE  \
# 0           0             9  2017  Autauga County,Alabama        55448
# 1           1            10  2018  Autauga County,Alabama        55533
# 2           2            11  2019  Autauga County,Alabama        55769
# 3           3             1  2020  Autauga County,Alabama        58877
# 4           4             2  2021  Autauga County,Alabama        59095
#
#     MFratio  POPEST_MALE  POPEST_FEM  MEDIAN_AGE_TOT  UNDER5_TOT  AGE513_TOT  \
# 0  0.951913        27041       28407            38.8        3286        6632
# 1  0.949621        27049       28484            39.1        3353        6490
# 2  0.943780        27078       28691            39.2        3251        6499
# 3  0.953256        28734       30143            39.2        3480        7042
# 4  0.946347        28733       30362            39.3        3388        7062
#
#    AGE1544_TOT  AGE4564_TOT  AGE65PLUS_TOT  Unnamed: 0_y  fips  \
# ...

# %%
pop=pop[pop.YEAR >=2019]
pop.head(5)
# Out:
#    Unnamed: 0  Unnamed: 0_x  YEAR                     C_S  POPESTIMATE  \
# 2           2            11  2019  Autauga County,Alabama        55769
# 3           3             1  2020  Autauga County,Alabama        58877
# 4           4             2  2021  Autauga County,Alabama        59095
# 7           7            25  2019  Baldwin County,Alabama       223565
# 8           8             4  2020  Baldwin County,Alabama       233140
#
#     MFratio  POPEST_MALE  POPEST_FEM  MEDIAN_AGE_TOT  UNDER5_TOT  AGE513_TOT  \
# 2  0.943780        27078       28691            39.2        3251        6499
# 3  0.953256        28734       30143            39.2        3480        7042
# 4  0.946347        28733       30362            39.3        3388        7062
# 7  0.941191       108396      115169            43.6       12068       24301
# 8  0.950505       113612      119528            43.8       12176       25601
#
#    AGE1544_TOT  AGE4564_TOT  AGE65PLUS_TOT  Unnamed: 0_y  fips  \
# ...

# %%
popclean = pop.filter(["fip-year","fips",'POPESTIMATE','MFratio','POPEST_MALE','POPEST_FEM','MEDIAN_AGE_TOT','UNDER5_TOT','AGE513_TOT','AGE1544_TOT','AGE4564_TOT','AGE65PLUS_TOT'], axis=1)
popclean.head(5)
# Out:
#     fip-year  fips  POPESTIMATE   MFratio  POPEST_MALE  POPEST_FEM  \
# 2  1001-2019  1001        55769  0.943780        27078       28691
# 3  1001-2020  1001        58877  0.953256        28734       30143
# 4  1001-2021  1001        59095  0.946347        28733       30362
# 7  1003-2019  1003       223565  0.941191       108396      115169
# 8  1003-2020  1003       233140  0.950505       113612      119528
#
#    MEDIAN_AGE_TOT  UNDER5_TOT  AGE513_TOT  AGE1544_TOT  AGE4564_TOT  \
# 2            39.2        3251        6499        21487        14933
# 3            39.2        3480        7042        22589        15672
# 4            39.3        3388        7062        22714        15600
# 7            43.6       12068       24301        76205        61216
# 8            43.8       12176       25601        79039        64092
#
#    AGE65PLUS_TOT
# 2           8783
# 3           9273
# 4           9484
# 7          46874
# 8          49125

# %%
popclean['fips']=popclean['fips'].astype(str)

popclean.dtypes
# Out:
# fip-year           object
# fips               object
# POPESTIMATE         int64
# MFratio           float64
# POPEST_MALE         int64
# POPEST_FEM          int64
# MEDIAN_AGE_TOT    float64
# UNDER5_TOT          int64
# AGE513_TOT          int64
# AGE1544_TOT         int64
# AGE4564_TOT         int64
# AGE65PLUS_TOT       int64
# dtype: object

# %%
popclean.to_csv('popclean.csv')

# %%
RU.head(5)
# Out:
#    Unnamed: 0  Unnamed: 0.1   FIPS State     County_Name Population_2010  \
# 0           0             0  01001    AL  Autauga County          54,571
# 1           1             1  01003    AL  Baldwin County         182,265
# 2           2             2  01005    AL  Barbour County          27,457
# 3           3             3  01007    AL     Bibb County          22,915
# 4           4             4  01009    AL   Blount County          57,322
#
#    RUCC_2013                                        Description   fips
# 0        2.0  Metro - Counties in metro areas of 250,000 to ...  01001
# 1        3.0  Metro - Counties in metro areas of fewer than ...  01003
# 2        6.0  Nonmetro - Urban population of 2,500 to 19,999...  01005
# 3        1.0  Metro - Counties in metro areas of 1 million p...  01007
# 4        1.0  Metro - Counties in metro areas of 1 million p...  01009

# %%
RUclean = RU.filter(['fips','RUCC_2013'], axis=1)
RUclean.head(5)
# Out:
#     fips  RUCC_2013
# 0  01001        2.0
# 1  01003        3.0
# 2  01005        6.0
# 3  01007        1.0
# 4  01009        1.0

# %%
RUclean.to_csv('RUclean.csv')

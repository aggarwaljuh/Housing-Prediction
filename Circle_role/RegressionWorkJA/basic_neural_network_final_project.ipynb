# %%
# import dependencies
import numpy as np
import pandas as pd
from pathlib import Path
from collections import Counter
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.model_selection import train_test_split
import tensorflow as tf
import sklearn as skl

# %%
#  Import and read the csv.
data_df = pd.read_csv("Triangle_role/Resources/sample_data.csv")
data_df.head()
# Out:
#    Year  FIPS                     C_S  month  cases  Pcincome  POPESTIMATE  \
# 0  2017  1001  Autauga County,Alabama      1      0     27824        55448
# 1  2017  1001  Autauga County,Alabama      2      0     27824        55448
# 2  2017  1001  Autauga County,Alabama      3      0     27824        55448
# 3  2017  1001  Autauga County,Alabama      4      0     27824        55448
# 4  2017  1001  Autauga County,Alabama      5      0     27824        55448
#
#     MFratio  POPEST_MALE  POPEST_FEM  ...     WA     BA   IA   AA  NA   TOM  \
# 0  0.951913        27041       28407  ...  42606  10816  254  693  59  1020
# 1  0.951913        27041       28407  ...  42606  10816  254  693  59  1020
# 2  0.951913        27041       28407  ...  42606  10816  254  693  59  1020
# 3  0.951913        27041       28407  ...  42606  10816  254  693  59  1020
# 4  0.951913        27041       28407  ...  42606  10816  254  693  59  1020
#
#       NH     H    Cost  RUCC
# 0  53908  1540  186712     2
# 1  53908  1540  186577     2
# 2  53908  1540  186397     2
# 3  53908  1540  186839     2
# 4  53908  1540  187155     2
#
# [5 rows x 26 columns]

# %%
#Using drop() to delete rows before 2019
data_df.drop(data_df[data_df['Year'] < 2019].index, inplace = True)
data_df.head()
# Out:
#     Year  FIPS                     C_S  month  cases  Pcincome  POPESTIMATE  \
# 24  2019  1001  Autauga County,Alabama      1      0     29819        55769
# 25  2019  1001  Autauga County,Alabama      2      0     29819        55769
# 26  2019  1001  Autauga County,Alabama      3      0     29819        55769
# 27  2019  1001  Autauga County,Alabama      4      0     29819        55769
# 28  2019  1001  Autauga County,Alabama      5      0     29819        55769
#
#     MFratio  POPEST_MALE  POPEST_FEM  ...     WA     BA   IA   AA  NA   TOM  \
# 24  0.94378        27078       28691  ...  42490  11252  266  668  58  1035
# 25  0.94378        27078       28691  ...  42490  11252  266  668  58  1035
# 26  0.94378        27078       28691  ...  42490  11252  266  668  58  1035
# 27  0.94378        27078       28691  ...  42490  11252  266  668  58  1035
# 28  0.94378        27078       28691  ...  42490  11252  266  668  58  1035
#
#        NH     H    Cost  RUCC
# 24  54116  1653  200156     2
# 25  54116  1653  200999     2
# 26  54116  1653  201698     2
# 27  54116  1653  202308     2
# 28  54116  1653  202854     2
#
# [5 rows x 26 columns]

# %%
data_df = data_df.drop(columns=["C_S"])
data_df.head()
# Out:
#     Year  FIPS  month  cases  Pcincome  POPESTIMATE  MFratio  POPEST_MALE  \
# 24  2019  1001      1      0     29819        55769  0.94378        27078
# 25  2019  1001      2      0     29819        55769  0.94378        27078
# 26  2019  1001      3      0     29819        55769  0.94378        27078
# 27  2019  1001      4      0     29819        55769  0.94378        27078
# 28  2019  1001      5      0     29819        55769  0.94378        27078
#
#     POPEST_FEM  MEDIAN_AGE_TOT  ...     WA     BA   IA   AA  NA   TOM     NH  \
# 24       28691            39.2  ...  42490  11252  266  668  58  1035  54116
# 25       28691            39.2  ...  42490  11252  266  668  58  1035  54116
# 26       28691            39.2  ...  42490  11252  266  668  58  1035  54116
# 27       28691            39.2  ...  42490  11252  266  668  58  1035  54116
# 28       28691            39.2  ...  42490  11252  266  668  58  1035  54116
#
#        H    Cost  RUCC
# 24  1653  200156     2
# 25  1653  200999     2
# 26  1653  201698     2
# 27  1653  202308     2
# 28  1653  202854     2
#
# [5 rows x 25 columns]

# %%
# Create the StandardScaler instance
scaler = StandardScaler()

# Fit the StandardScaler
scaler.fit(data_df)

# Scale the data
scaled_data = scaler.transform(data_df)

# %%
# Create a DataFrame with the scaled data
scaled_data = pd.DataFrame(scaled_data, columns=data_df.columns)
scaled_data.head()
# Out:
#        Year      FIPS     month     cases  Pcincome  POPESTIMATE   MFratio  \
# 0 -1.224745 -1.705574 -1.593255 -0.560116 -0.098628    -1.156716 -0.761345
# 1 -1.224745 -1.705574 -1.303572 -0.560116 -0.098628    -1.156716 -0.761345
# 2 -1.224745 -1.705574 -1.013890 -0.560116 -0.098628    -1.156716 -0.761345
# 3 -1.224745 -1.705574 -0.724207 -0.560116 -0.098628    -1.156716 -0.761345
# 4 -1.224745 -1.705574 -0.434524 -0.560116 -0.098628    -1.156716 -0.761345
#
#    POPEST_MALE  POPEST_FEM  MEDIAN_AGE_TOT  ...        WA        BA        IA  \
# 0    -1.134408   -1.179301       -0.265989  ... -0.868996 -0.349267 -0.546559
# 1    -1.134408   -1.179301       -0.265989  ... -0.868996 -0.349267 -0.546559
# 2    -1.134408   -1.179301       -0.265989  ... -0.868996 -0.349267 -0.546559
# 3    -1.134408   -1.179301       -0.265989  ... -0.868996 -0.349267 -0.546559
# 4    -1.134408   -1.179301       -0.265989  ... -0.868996 -0.349267 -0.546559
#
#          AA        NA       TOM        NH         H      Cost      RUCC
# 0 -0.568558 -0.454621 -0.790283 -0.798232 -0.581731  0.521240 -0.390567
# 1 -0.568558 -0.454621 -0.790283 -0.798232 -0.581731  0.539230 -0.390567
# 2 -0.568558 -0.454621 -0.790283 -0.798232 -0.581731  0.554147 -0.390567
# 3 -0.568558 -0.454621 -0.790283 -0.798232 -0.581731  0.567165 -0.390567
# 4 -0.568558 -0.454621 -0.790283 -0.798232 -0.581731  0.578816 -0.390567
#
# [5 rows x 25 columns]

# %%
# Split our preprocessed data into our features and target arrays
y = scaled_data["Cost"].values
X = scaled_data.drop(["Cost"],1).values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=22)
# Out:
# C:\Users\dog\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# Create scaler instance
X_scaler = skl.preprocessing.StandardScaler()

# Fit the scaler
X_scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Create the Keras Sequential model
nn_model = tf.keras.models.Sequential()

# %%
# Add our first Dense layer, including the input layer
nn_model.add(tf.keras.layers.Dense(units=1, activation="relu", input_dim=24))

# %%
# Add the output layer that uses a probability activation function
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# %%
# Check the structure of the Sequential model
nn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 25
#
#  dense_1 (Dense)             (None, 1)                 2
#
# =================================================================
# Total params: 27
# Trainable params: 27
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the Sequential model together and customize metrics
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Fit the model to the training data
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 4/4 [==============================] - 2s 6ms/step - loss: -0.0368 - accuracy: 0.0000e+00
# Epoch 2/100
# 4/4 [==============================] - 0s 8ms/step - loss: -0.0599 - accuracy: 0.0000e+00
# Epoch 3/100
# 4/4 [==============================] - 0s 9ms/step - loss: -0.0821 - accuracy: 0.0000e+00
# Epoch 4/100
# 4/4 [==============================] - 0s 7ms/step - loss: -0.1042 - accuracy: 0.0000e+00
# Epoch 5/100
# 4/4 [==============================] - 0s 14ms/step - loss: -0.1273 - accuracy: 0.0000e+00
# Epoch 6/100
# 4/4 [==============================] - 0s 7ms/step - loss: -0.1530 - accuracy: 0.0000e+00
# Epoch 7/100
# 4/4 [==============================] - 0s 8ms/step - loss: -0.1749 - accuracy: 0.0000e+00
# Epoch 8/100
# 4/4 [==============================] - 0s 17ms/step - loss: -0.1961 - accuracy: 0.0000e+00
# Epoch 9/100
# 4/4 [==============================] - 0s 10ms/step - loss: -0.2219 - accuracy: 0.0000e+00
# Epoch 10/100
# 4/4 [==============================] - 0s 8ms/step - loss: -0.2457 - accuracy: 0.0000e+00
# Epoch 11/100
# 4/4 [==============================] - 0s 19ms/step - loss: -0.2688 - accuracy: 0.0000e+00
# Epoch 12/100
# 4/4 [==============================] - ETA: 0s - loss: -0.6026 - accuracy: 0.0000e+0 - 0s 16ms/step - loss: -0.2920 - accuracy: 0.0000e+00
# Epoch 13/100
# 4/4 [==============================] - 0s 15ms/step - loss: -0.3194 - accuracy: 0.0000e+00
# Epoch 14/100
# 4/4 [==============================] - 0s 12ms/step - loss: -0.3417 - accuracy: 0.0000e+00
# Epoch 15/100
# 4/4 [==============================] - 0s 14ms/step - loss: -0.3672 - accuracy: 0.0000e+00
# Epoch 16/100
# 4/4 [==============================] - 0s 22ms/step - loss: -0.3926 - accuracy: 0.0000e+00: 0s - loss: -0.3926 - accuracy: 0.0000e+0
# Epoch 17/100
# 4/4 [==============================] - 0s 7ms/step - loss: -0.4182 - accuracy: 0.0000e+00
# Epoch 18/100
# 4/4 [==============================] - 0s 13ms/step - loss: -0.4420 - accuracy: 0.0000e+00
# Epoch 19/100
# 4/4 [==============================] - ETA: 0s - loss: -0.7274 - accuracy: 0.0000e+0 - 0s 11ms/step - loss: -0.4690 - accuracy: 0.0000e+00
# Epoch 20/100
# 4/4 [==============================] - 0s 9ms/step - loss: -0.4943 - accuracy: 0.0000e+00
# Epoch 21/100
# 4/4 [==============================] - 0s 10ms/step - loss: -0.5205 - accuracy: 0.0000e+00
# Epoch 22/100
# 4/4 [==============================] - 0s 10ms/step - loss: -0.5450 - accuracy: 0.0000e+00
# Epoch 23/100
# 4/4 [==============================] - 0s 10ms/step - loss: -0.5733 - accuracy: 0.0000e+00
# Epoch 24/100
# 4/4 [==============================] - 0s 8ms/step - loss: -0.5993 - accuracy: 0.0000e+00
# Epoch 25/100
# 4/4 [==============================] - 0s 9ms/step - loss: -0.6263 - accuracy: 0.0000e+00
# Epoch 26/100
# 4/4 [==============================] - 0s 9ms/step - loss: -0.6544 - accuracy: 0.0000e+00
# Epoch 27/100
# 4/4 [==============================] - 0s 11ms/step - loss: -0.6831 - accuracy: 0.0000e+00
# Epoch 28/100
# 4/4 [==============================] - 0s 8ms/step - loss: -0.7128 - accuracy: 0.0000e+00
# Epoch 29/100
# 4/4 [==============================] - 0s 8ms/step - loss: -0.7406 - accuracy: 0.0000e+00
# Epoch 30/100
# 4/4 [==============================] - 0s 7ms/step - loss: -0.7737 - accuracy: 0.0000e+00
# Epoch 31/100
# 4/4 [==============================] - 0s 10ms/step - loss: -0.8028 - accuracy: 0.0000e+00
# Epoch 32/100
# 4/4 [==============================] - 0s 6ms/step - loss: -0.8339 - accuracy: 0.0000e+00
# Epoch 33/100
# 4/4 [==============================] - 0s 9ms/step - loss: -0.8657 - accuracy: 0.0000e+00
# Epoch 34/100
# 4/4 [==============================] - 0s 9ms/step - loss: -0.8997 - accuracy: 0.0000e+00
# Epoch 35/100
# 4/4 [==============================] - 0s 6ms/step - loss: -0.9294 - accuracy: 0.0000e+00
# Epoch 36/100
# 4/4 [==============================] - 0s 7ms/step - loss: -0.9642 - accuracy: 0.0000e+00
# Epoch 37/100
# 4/4 [==============================] - 0s 6ms/step - loss: -0.9946 - accuracy: 0.0000e+00
# Epoch 38/100
# 4/4 [==============================] - 0s 6ms/step - loss: -1.0306 - accuracy: 0.0000e+00
# Epoch 39/100
# 4/4 [==============================] - 0s 6ms/step - loss: -1.0651 - accuracy: 0.0000e+00
# Epoch 40/100
# 4/4 [==============================] - 0s 6ms/step - loss: -1.0981 - accuracy: 0.0000e+00
# Epoch 41/100
# 4/4 [==============================] - 0s 5ms/step - loss: -1.1330 - accuracy: 0.0000e+00
# Epoch 42/100
# 4/4 [==============================] - 0s 9ms/step - loss: -1.1664 - accuracy: 0.0000e+00
# Epoch 43/100
# 4/4 [==============================] - 0s 6ms/step - loss: -1.2080 - accuracy: 0.0000e+00
# Epoch 44/100
# 4/4 [==============================] - 0s 7ms/step - loss: -1.2395 - accuracy: 0.0000e+00
# Epoch 45/100
# 4/4 [==============================] - 0s 7ms/step - loss: -1.2751 - accuracy: 0.0000e+00
# Epoch 46/100
# 4/4 [==============================] - 0s 8ms/step - loss: -1.3151 - accuracy: 0.0000e+00
# Epoch 47/100
# 4/4 [==============================] - 0s 11ms/step - loss: -1.3505 - accuracy: 0.0000e+00
# Epoch 48/100
# 4/4 [==============================] - 0s 9ms/step - loss: -1.3902 - accuracy: 0.0000e+00
# Epoch 49/100
# 4/4 [==============================] - 0s 12ms/step - loss: -1.4271 - accuracy: 0.0000e+00
# Epoch 50/100
# 4/4 [==============================] - 0s 7ms/step - loss: -1.4653 - accuracy: 0.0000e+00
# Epoch 51/100
# 4/4 [==============================] - 0s 7ms/step - loss: -1.5053 - accuracy: 0.0000e+00
# Epoch 52/100
# 4/4 [==============================] - 0s 7ms/step - loss: -1.5468 - accuracy: 0.0000e+00
# Epoch 53/100
# 4/4 [==============================] - 0s 6ms/step - loss: -1.5852 - accuracy: 0.0000e+00
# Epoch 54/100
# 4/4 [==============================] - 0s 7ms/step - loss: -1.6267 - accuracy: 0.0000e+00
# Epoch 55/100
# 4/4 [==============================] - 0s 7ms/step - loss: -1.6673 - accuracy: 0.0000e+00
# Epoch 56/100
# 4/4 [==============================] - 0s 9ms/step - loss: -1.7116 - accuracy: 0.0000e+00
# Epoch 57/100
# 4/4 [==============================] - ETA: 0s - loss: -0.8388 - accuracy: 0.0000e+0 - 0s 17ms/step - loss: -1.7566 - accuracy: 0.0000e+00
# Epoch 58/100
# 4/4 [==============================] - 0s 8ms/step - loss: -1.7989 - accuracy: 0.0000e+00
# Epoch 59/100
# 4/4 [==============================] - 0s 8ms/step - loss: -1.8421 - accuracy: 0.0000e+00
# Epoch 60/100
# 4/4 [==============================] - 0s 9ms/step - loss: -1.8851 - accuracy: 0.0000e+00
# Epoch 61/100
# 4/4 [==============================] - 0s 6ms/step - loss: -1.9268 - accuracy: 0.0000e+00
# Epoch 62/100
# 4/4 [==============================] - 0s 7ms/step - loss: -1.9724 - accuracy: 0.0000e+00
# Epoch 63/100
# 4/4 [==============================] - 0s 8ms/step - loss: -2.0154 - accuracy: 0.0000e+00
# Epoch 64/100
# 4/4 [==============================] - 0s 7ms/step - loss: -2.0596 - accuracy: 0.0000e+00
# Epoch 65/100
# 4/4 [==============================] - 0s 7ms/step - loss: -2.1055 - accuracy: 0.0000e+00
# Epoch 66/100
# 4/4 [==============================] - 0s 7ms/step - loss: -2.1546 - accuracy: 0.0000e+00
# Epoch 67/100
# 4/4 [==============================] - 0s 7ms/step - loss: -2.1986 - accuracy: 0.0000e+00
# Epoch 68/100
# 4/4 [==============================] - 0s 11ms/step - loss: -2.2444 - accuracy: 0.0000e+00
# Epoch 69/100
# 4/4 [==============================] - 0s 10ms/step - loss: -2.2971 - accuracy: 0.0000e+00
# Epoch 70/100
# 4/4 [==============================] - 0s 9ms/step - loss: -2.3420 - accuracy: 0.0000e+00
# Epoch 71/100
# 4/4 [==============================] - 0s 8ms/step - loss: -2.3899 - accuracy: 0.0000e+00
# Epoch 72/100
# 4/4 [==============================] - 0s 7ms/step - loss: -2.4370 - accuracy: 0.0000e+00
# Epoch 73/100
# 4/4 [==============================] - 0s 8ms/step - loss: -2.4914 - accuracy: 0.0000e+00
# Epoch 74/100
# 4/4 [==============================] - 0s 9ms/step - loss: -2.5373 - accuracy: 0.0000e+00
# Epoch 75/100
# 4/4 [==============================] - 0s 6ms/step - loss: -2.5862 - accuracy: 0.0000e+00
# Epoch 76/100
# 4/4 [==============================] - ETA: 0s - loss: -2.2888 - accuracy: 0.0000e+0 - 0s 8ms/step - loss: -2.6371 - accuracy: 0.0000e+00
# Epoch 77/100
# 4/4 [==============================] - 0s 9ms/step - loss: -2.6861 - accuracy: 0.0000e+00
# Epoch 78/100
# 4/4 [==============================] - 0s 9ms/step - loss: -2.7391 - accuracy: 0.0000e+00
# Epoch 79/100
# 4/4 [==============================] - 0s 10ms/step - loss: -2.7884 - accuracy: 0.0000e+00
# Epoch 80/100
# 4/4 [==============================] - ETA: 0s - loss: -2.0394 - accuracy: 0.0000e+0 - 0s 9ms/step - loss: -2.8452 - accuracy: 0.0000e+00
# Epoch 81/100
# 4/4 [==============================] - 0s 10ms/step - loss: -2.8953 - accuracy: 0.0000e+00
# Epoch 82/100
# 4/4 [==============================] - 0s 10ms/step - loss: -2.9515 - accuracy: 0.0000e+00
# Epoch 83/100
# 4/4 [==============================] - 0s 10ms/step - loss: -3.0072 - accuracy: 0.0000e+00
# Epoch 84/100
# 4/4 [==============================] - 0s 10ms/step - loss: -3.0679 - accuracy: 0.0000e+00
# Epoch 85/100
# 4/4 [==============================] - 0s 11ms/step - loss: -3.1216 - accuracy: 0.0000e+00
# Epoch 86/100
# 4/4 [==============================] - 0s 10ms/step - loss: -3.1796 - accuracy: 0.0000e+00
# Epoch 87/100
# 4/4 [==============================] - 0s 9ms/step - loss: -3.2364 - accuracy: 0.0000e+00
# Epoch 88/100
# 4/4 [==============================] - 0s 10ms/step - loss: -3.2991 - accuracy: 0.0000e+00
# Epoch 89/100
# 4/4 [==============================] - 0s 11ms/step - loss: -3.3557 - accuracy: 0.0000e+00
# Epoch 90/100
# 4/4 [==============================] - ETA: 0s - loss: -3.5269 - accuracy: 0.0000e+0 - 0s 12ms/step - loss: -3.4128 - accuracy: 0.0000e+00
# Epoch 91/100
# 4/4 [==============================] - 0s 8ms/step - loss: -3.4726 - accuracy: 0.0000e+00
# Epoch 92/100
# 4/4 [==============================] - 0s 8ms/step - loss: -3.5295 - accuracy: 0.0000e+00
# Epoch 93/100
# 4/4 [==============================] - 0s 7ms/step - loss: -3.5918 - accuracy: 0.0000e+00
# Epoch 94/100
# 4/4 [==============================] - 0s 10ms/step - loss: -3.6536 - accuracy: 0.0000e+00
# Epoch 95/100
# 4/4 [==============================] - 0s 9ms/step - loss: -3.7131 - accuracy: 0.0000e+00
# Epoch 96/100
# 4/4 [==============================] - 0s 8ms/step - loss: -3.7695 - accuracy: 0.0000e+00
# Epoch 97/100
# 4/4 [==============================] - 0s 11ms/step - loss: -3.8303 - accuracy: 0.0000e+00
# Epoch 98/100
# 4/4 [==============================] - 0s 9ms/step - loss: -3.8937 - accuracy: 0.0000e+00
# Epoch 99/100
# 4/4 [==============================] - 0s 11ms/step - loss: -3.9448 - accuracy: 0.0000e+00
# Epoch 100/100
# 4/4 [==============================] - 0s 16ms/step - loss: -4.0099 - accuracy: 0.0000e+00

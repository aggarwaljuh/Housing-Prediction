# %%
import pandas as pd
Zillow = pd.read_csv('Zillowdata.csv')
states = pd.read_csv('FIPS.csv')
COVID= pd.read_csv('cleancovid.csv')
income= pd.read_csv('incomeall.csv')
raceeth= pd.read_csv('RaceEthnicity.csv')
RU= pd.read_csv('ruralurban.csv')
Zillow
# Out:
#       Unnamed: 0  RegionID  SizeRank          RegionName RegionType StateName  \
# 0              0      3101         0  Los Angeles County     county        CA
# 1              1       139         1         Cook County     county        IL
# 2              2      1090         2       Harris County     county        TX
# 3              3      2402         3     Maricopa County     county        AZ
# 4              4      2841         4    San Diego County     county        CA
# ...          ...       ...       ...                 ...        ...       ...
# 2835        2835       828      3104       Alpine County     county        CA
# 2836        2836      2345      3113     Hinsdale County     county        CO
# 2837        2837      1933      3114      Mineral County     county        CO
# 2838        2838      1648      3129      Daggett County     county        UT
# 2839        2839      2518      3132     San Juan County     county        CO
#
# ...

# %%
states['C_Sa']=states['name'].astype(str)+','+states['state_Ab'].astype(str)
states
# Out:
#       Unnamed: 0   fips               name state_Ab    state  \
# 0              0   1001     Autauga County       AL  Alabama
# 1              1   1003     Baldwin County       AL  Alabama
# 2              2   1005     Barbour County       AL  Alabama
# 3              3   1007        Bibb County       AL  Alabama
# 4              4   1009      Blount County       AL  Alabama
# ...          ...    ...                ...      ...      ...
# 3138        3138  56037  Sweetwater County       WY  Wyoming
# 3139        3139  56039       Teton County       WY  Wyoming
# 3140        3140  56041       Uinta County       WY  Wyoming
# 3141        3141  56043    Washakie County       WY  Wyoming
# 3142        3142  56045      Weston County       WY  Wyoming
#
#                             C_S                  C_Sa
# 0        Autauga County,Alabama     Autauga County,AL
# 1        Baldwin County,Alabama     Baldwin County,AL
# 2        Barbour County,Alabama     Barbour County,AL
# ...

# %%
Zillow['C_Sa']=Zillow['RegionName'].astype(str)+','+Zillow['StateName'].astype(str)
Zillow
# Out:
#       Unnamed: 0  RegionID  SizeRank          RegionName RegionType StateName  \
# 0              0      3101         0  Los Angeles County     county        CA
# 1              1       139         1         Cook County     county        IL
# 2              2      1090         2       Harris County     county        TX
# 3              3      2402         3     Maricopa County     county        AZ
# 4              4      2841         4    San Diego County     county        CA
# ...          ...       ...       ...                 ...        ...       ...
# 2835        2835       828      3104       Alpine County     county        CA
# 2836        2836      2345      3113     Hinsdale County     county        CO
# 2837        2837      1933      3114      Mineral County     county        CO
# 2838        2838      1648      3129      Daggett County     county        UT
# 2839        2839      2518      3132     San Juan County     county        CO
#
# ...

# %%
Zillow.merge(states, on="C_Sa")
# Out:
#       Unnamed: 0_x  RegionID  SizeRank          RegionName RegionType  \
# 0                0      3101         0  Los Angeles County     county
# 1                1       139         1         Cook County     county
# 2                2      1090         2       Harris County     county
# 3                3      2402         3     Maricopa County     county
# 4                4      2841         4    San Diego County     county
# ...            ...       ...       ...                 ...        ...
# 2749          2835       828      3104       Alpine County     county
# 2750          2836      2345      3113     Hinsdale County     county
# 2751          2837      1933      3114      Mineral County     county
# 2752          2838      1648      3129      Daggett County     county
# 2753          2839      2518      3132     San Juan County     county
#
#      StateName State                                 Metro  StateCodeFIPS  \
# ...

# %%
COVID['fip-year-month']=COVID['fips'].astype(str)+'-'+COVID['Unnamed: 0'].astype(str)+'-'+COVID['date'].astype(str)
COVID['fip-year']=COVID['fips'].astype(str)+'-'+COVID['Unnamed: 0'].astype(str)
COVID
# Out:
#        Unnamed: 0   fips  date  cases fip-year-month    fip-year
# 0            2020   1001     3     43    1001-2020-3   1001-2020
# 1            2020   1001     4    731    1001-2020-4   1001-2020
# 2            2020   1001     5   3660    1001-2020-5   1001-2020
# 3            2020   1001     6  11110    1001-2020-6   1001-2020
# 4            2020   1001     7  24241    1001-2020-7   1001-2020
# ...           ...    ...   ...    ...            ...         ...
# 67348        2021  56045     8  22442   56045-2021-8  56045-2021
# 67349        2021  56045     9  25372   56045-2021-9  56045-2021
# 67350        2021  56045    10  30816  56045-2021-10  56045-2021
# 67351        2021  56045    11  35174  56045-2021-11  56045-2021
# 67352        2021  56045    12  38058  56045-2021-12  56045-2021
#
# [67353 rows x 6 columns]

# %%
income['fip-year']=income['fips'].astype(str)+'-'+income['Unnamed: 0'].astype(str)
income
# Out:
#        Unnamed: 0  Unnamed: 1   fips  PCIncome  year    fip-year
# 0            2017           1   1001   27824.0  2017   1001-2017
# 1            2017           2   1003   29364.0  2017   1003-2017
# 2            2017           3   1005   17561.0  2017   1005-2017
# 3            2017           4   1007   20911.0  2017   1007-2017
# 4            2017           5   1009   22021.0  2017   1009-2017
# ...           ...         ...    ...       ...   ...         ...
# 16102        2021        3218  72147    8834.0  2021  72147-2021
# 16103        2021        3219  72149   12179.0  2021  72149-2021
# 16104        2021        3220  72151   10507.0  2021  72151-2021
# 16105        2021        3221  72153   10231.0  2021  72153-2021
# 16106        2021        3222      0   37638.0  2021      0-2021
#
# [16107 rows x 6 columns]

# %%
raceeth=raceeth.merge(states, on="C_S")
raceeth
# Out:
#        Unnamed: 0_x  YEAR                     C_S     WA     BA   IA   AA  NA  \
# 0                 9  2017  Autauga County,Alabama  42606  10816  254  693  59
# 1                10  2018  Autauga County,Alabama  42641  10883  263  671  61
# 2                11  2019  Autauga County,Alabama  42490  11252  266  668  58
# 3                19  2020  Autauga County,Alabama  44580  12136  281  690  66
# 4                38  2021  Autauga County,Alabama  44442  12425  271  711  70
# ...             ...   ...                     ...    ...    ...  ...  ...  ..
# 15675         43997  2017   Weston County,Wyoming   6560     44  117   94   2
# 15676         43998  2018   Weston County,Wyoming   6456     47  127  100   2
# 15677         43999  2019   Weston County,Wyoming   6429     48  132   98   2
# 15678        179113  2020   Weston County,Wyoming   6377     48  127   93   1
# 15679        179132  2021   Weston County,Wyoming   6310     49  128   96   1
#
# ...

# %%
raceeth['fip-year']=raceeth['fips'].astype(str)+'-'+raceeth['YEAR'].astype(str)
raceeth
# Out:
#        Unnamed: 0_x  YEAR                     C_S     WA     BA   IA   AA  NA  \
# 0                 9  2017  Autauga County,Alabama  42606  10816  254  693  59
# 1                10  2018  Autauga County,Alabama  42641  10883  263  671  61
# 2                11  2019  Autauga County,Alabama  42490  11252  266  668  58
# 3                19  2020  Autauga County,Alabama  44580  12136  281  690  66
# 4                38  2021  Autauga County,Alabama  44442  12425  271  711  70
# ...             ...   ...                     ...    ...    ...  ...  ...  ..
# 15675         43997  2017   Weston County,Wyoming   6560     44  117   94   2
# 15676         43998  2018   Weston County,Wyoming   6456     47  127  100   2
# 15677         43999  2019   Weston County,Wyoming   6429     48  132   98   2
# 15678        179113  2020   Weston County,Wyoming   6377     48  127   93   1
# 15679        179132  2021   Weston County,Wyoming   6310     49  128   96   1
#
# ...

# %%
RU['fips']=RU["FIPS"]
COVID['fips']=COVID['fips'].astype(str)
states['fips']=states['fips'].astype(str)
RU['fips']=RU['fips'].astype(str)
RU.merge(states, on='fips')
RU
# Out:
#       Unnamed: 0   FIPS State     County_Name Population_2010  RUCC_2013  \
# 0              0  01001    AL  Autauga County          54,571        2.0
# 1              1  01003    AL  Baldwin County         182,265        3.0
# 2              2  01005    AL  Barbour County          27,457        6.0
# 3              3  01007    AL     Bibb County          22,915        1.0
# 4              4  01009    AL   Blount County          57,322        1.0
# ...          ...    ...   ...             ...             ...        ...
# 3235        3235  00nan   NaN             NaN             NaN        NaN
# 3236        3236  00nan   NaN             NaN             NaN        NaN
# 3237        3237  00nan   NaN             NaN             NaN        NaN
# 3238        3238  00nan   NaN             NaN             NaN        NaN
# 3239        3239  00nan   NaN             NaN             NaN        NaN
#
#                                             Description   fips
# ...

# %%
RU.dropna()
# Out:
#       Unnamed: 0   FIPS State        County_Name Population_2010  RUCC_2013  \
# 0              0  01001    AL     Autauga County          54,571        2.0
# 1              1  01003    AL     Baldwin County         182,265        3.0
# 2              2  01005    AL     Barbour County          27,457        6.0
# 3              3  01007    AL        Bibb County          22,915        1.0
# 4              4  01009    AL      Blount County          57,322        1.0
# ...          ...    ...   ...                ...             ...        ...
# 3229        3229  72151    PR  Yabucoa Municipio          37,941        1.0
# 3230        3230  72153    PR    Yauco Municipio          42,043        2.0
# 3231        3231  78010    VI   St. Croix Island          50,601        5.0
# 3232        3232  78020    VI    St. John Island           4,170        7.0
# 3233        3233  78030    VI  St. Thomas Island          51,634        5.0
#
# ...

# %%
COVID.dtypes
COVID['fips']=COVID['fips'].astype(str)
COVID.dtypes
# Out:
# Unnamed: 0     int64
# fips          object
# date           int64
# cases          int64
# dtype: object

# %%
COVIDT=COVID.set_index(['fip-year-month']).T
COVIDT
# Out:
# fip-year-month 1001-2020-3 1001-2020-4 1001-2020-5 1001-2020-6 1001-2020-7  \
# Unnamed: 0            2020        2020        2020        2020        2020
# fips                  1001        1001        1001        1001        1001
# date                     3           4           5           6           7
# cases                   43         731        3660       11110       24241
# fip-year         1001-2020   1001-2020   1001-2020   1001-2020   1001-2020
#
# fip-year-month 1001-2020-8 1001-2020-9 1001-2020-10 1001-2020-11 1001-2020-12  \
# Unnamed: 0            2020        2020         2020         2020         2020
# fips                  1001        1001         1001         1001         1001
# date                     8           9           10           11           12
# cases                38807       48577        60844        73997       108652
# fip-year         1001-2020   1001-2020    1001-2020    1001-2020    1001-2020
#
# ...

# %%
income1=income.merge(COVID, on='fip-year')
income2=income.rename(column
income2=income1[['fip-year-month_y','PCIncome']]
income3=income2.set_index(['fip-year-month_y']).T
income3
# Out:
# fip-year-month_y  1001-2020-3  1001-2020-4  1001-2020-5  1001-2020-6  \
# PCIncome              29804.0      29804.0      29804.0      29804.0
#
# fip-year-month_y  1001-2020-7  1001-2020-8  1001-2020-9  1001-2020-10  \
# PCIncome              29804.0      29804.0      29804.0       29804.0
#
# fip-year-month_y  1001-2020-11  1001-2020-12  ...  56045-2021-3  56045-2021-4  \
# PCIncome               29804.0       29804.0  ...       31190.0       31190.0
#
# fip-year-month_y  56045-2021-5  56045-2021-6  56045-2021-7  56045-2021-8  \
# PCIncome               31190.0       31190.0       31190.0       31190.0
#
# fip-year-month_y  56045-2021-9  56045-2021-10  56045-2021-11  56045-2021-12
# PCIncome               31190.0        31190.0        31190.0        31190.0
#
# [1 rows x 736101 columns]

# %%
COVIDINCOME=pd.concat([COVIDT,income3], ignore_index=True)
COVIDINCOME
# Out:
# ---------------------------------------------------------------------------
# InvalidIndexError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20200\2304941083.py in <module>
# ----> 1 COVIDINCOME=pd.concat([COVIDT,income3], ignore_index=True)
#       2 COVIDINCOME
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     305     )
#     306
# --> 307     return op.get_result()
#     308
#     309
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\core\reshape\concat.py in get_result(self)
#     526                     obj_labels = obj.axes[1 - ax]
# ...
